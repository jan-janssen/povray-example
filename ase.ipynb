# %%
import subprocess

# %%
from IPython.display import Image, display

# %%
from ase import Atoms
from ase.build import fcc111, add_adsorbate
from ase.io import write

# %%
adsorbate = Atoms('CO')
adsorbate[1].z = 1.1
a = 3.61
slab = fcc111('Cu', (2, 2, 3), a=a, vacuum=7.0)
add_adsorbate(slab, adsorbate, 1.8, 'ontop')

# %%
write('slab.pov', slab * (3, 3, 1), rotation='10z,-80x')

# %%
subprocess.check_output(["povray", "+H800", "+W800", "+Islab.pov", "+Oslab.png", "+UA"])
# Out:
# b''

# %%
display(Image("slab.png"))
